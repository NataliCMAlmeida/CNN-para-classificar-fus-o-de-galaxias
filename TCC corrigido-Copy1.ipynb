# %%
#Bibliotecas
import astropy.io.fits as fits
import numpy as np
import matplotlib.pyplot as plt
from astropy.visualization import simple_norm
import time
from scipy.ndimage import zoom, gaussian_filter
import random
from sklearn.model_selection import train_test_split
from scipy.ndimage import rotate
from numpy.random import choice
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.activations import elu
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers
import time
import tensorflow as tf
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, accuracy_score, precision_score, recall_score, f1_score, brier_score_loss, classification_report
from matplotlib.colors import LogNorm
import seaborn as sns
from tensorflow import keras

# %%
start_time = time.time()
datafile_path = r"C:\Users\Cliente\Documents\TCC NATALI\hlsp_deepmerge_hst_acs-wfc3_illustris-z2_f814w-f160w_v1_sim-pristine.fits"

hdulist = fits.open(datafile_path)
header = hdulist[0].header

X = np.array(hdulist[0].data)
Y = np.array(hdulist[1].data)

t_file_read = time.time()-start_time
print("tempo para ler dados do arquivo: {:0.3f} s".format(t_file_read))

shape_hdu0 = X.data.shape
shape_hdu1 = Y.shape
print(f"Shape do HDU0 (Images): {shape_hdu0}")
print(f"Shape do HDU1 (Label): {shape_hdu1}")
# Out:
# tempo para ler dados do arquivo: 2.096 s
# Shape do HDU0 (Images): (15426, 2, 75, 75)
# Shape do HDU1 (Label): (15426,)

# %%
plot_sample_images = True
np.random.seed(206265)

examples_f160w = [hdulist[0].data[j, 1, :, :] for j in range(shape_hdu0[0])]
examples_f814w = [hdulist[0].data[j, 0, :, :] for j in range(shape_hdu0[0])]

if plot_sample_images:
    example_ids = np.random.choice(len(hdulist[0].data), 2)  # Seleciona 4 IDs aleatórios
    print("\nExemplo de imagens por filtros:\n")
    print(f'{example_ids}\n')

    # F160W filtro  no infravermelho próximo a luz visível ~ 840 nm (NIR)
    # F814W filtro no infravermelho ~ 1600nm  (FIR)

    fig = plt.figure(figsize=(11, 8))

    # Criando um loop para mostrar cada imagem com o respectivo rótulo
    for i, example_id in enumerate(example_ids):
        # F160W
        ax1 = fig.add_subplot(4, 2, (i * 2) + 1)  # Use (i * 2) + 1 como índice
        norm1 = simple_norm(hdulist[0].data[example_id, 1, :, :], 'log', max_percent=99.75)  # Acessa imagem correta
        ax1.imshow(hdulist[0].data[example_id, 1, :, :], aspect='equal', cmap='gray', norm=norm1)
        ax1.set_title('F160W - Fusão=' + str(bool(Y[example_id])))  # Usa o rótulo correto
        ax1.axis('off')

        # F814W
        ax2 = fig.add_subplot(4, 2, (i * 2) + 2)  # Use (i * 2) + 2 como índice
        norm2 = simple_norm(hdulist[0].data[example_id, 0, :, :], 'log', max_percent=99.75)  # Acessa imagem correta
        ax2.imshow(hdulist[0].data[example_id, 0, :, :], aspect='equal', cmap='gray', norm=norm2)
        ax2.set_title('F814W - Fusão=' + str(bool(Y[example_id])))  # Usa o rótulo correto
        ax2.axis('off')

    plt.tight_layout()
    plt.show()

# %%
data_hdu1_vec = np.array([y[0] for y in Y])
list_of_mergers = np.where(data_hdu1_vec == 1.)[0]
list_of_nonmergers = np.where(data_hdu1_vec == 0.)[0]

print(f"Shape de list_of_mergers (label = 1): {list_of_mergers.shape}")
print(f"Shape de list_of_nonmergers (label = 0): {list_of_nonmergers.shape}")
# Out:
# Shape de list_of_mergers (label = 1): (8120,)
# Shape de list_of_nonmergers (label = 0): (7306,)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Define the proportions:
train_ratio = 0.7
validation_ratio = 0.1
test_ratio = 0.2

# Round the sum to ensure it equals 1.0
rounded_sum = round(train_ratio + validation_ratio + test_ratio, 10)  # Adjust decimal places as needed
assert rounded_sum == 1.0

# Divide os dados em treino e (teste + validação)
X_train, X_temp, Y_train, Y_temp = train_test_split(
    X, Y, test_size=(validation_ratio + test_ratio), random_state=42, shuffle=True, stratify=Y
)

# Divide o conjunto temporário em teste e validação
X_validation, X_test, Y_validation, Y_test = train_test_split(
    X_temp, Y_temp, test_size=test_ratio / (validation_ratio + test_ratio), random_state=42, shuffle=True, stratify=Y_temp
)

print("Tamanho do conjunto de treinamento:", X_train.shape[0])
print("Tamanho do conjunto de validação:", X_validation.shape[0])
print("Tamanho do conjunto de teste:", X_test.shape[0])
# Out:
# Tamanho do conjunto de treinamento: 10798
# Tamanho do conjunto de validação: 1542
# Tamanho do conjunto de teste: 3086

# %%
#Calcula a média e o desvio padrão do conjunto de treinamento.
#Normaliza os dados de treinamento, validação e teste utilizando a média e o desvio padrão do conjunto de treinamento.
mean_train = np.mean(X_train)
std_train = np.std(X_train)

X_train = (X_train - mean_train) / std_train
X_validation = (X_validation - mean_train) / std_train
X_test = (X_test - mean_train) / std_train

# %%
#Arquitetura da rede

t_NN_creation = time.time()

# Arquitetura da Rede (com as melhorias)
input_shape = (2, 75, 75) 

input_tensor = layers.Input(shape=input_shape)

x = layers.Conv2D(32, (5, 5), activation=elu, strides=(1, 1), padding='same', data_format='channels_first')(input_tensor)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid', data_format='channels_first')(x) 
x = layers.Dropout(0.4)(x) 

x = layers.Conv2D(64, (3, 3), activation=elu, strides=(1, 1), padding='same', data_format='channels_first')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid', data_format='channels_first')(x)
x = layers.Dropout(0.4)(x) 

x = layers.Flatten()(x)
x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.05))(x) 
x = layers.Dropout(0.4)(x)
x = layers.Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.05))(x) 
x = layers.Dropout(0.4)(x)

output_tensor = layers.Dense(1, activation='sigmoid')(x)

model = keras.Model(inputs=input_tensor, outputs=output_tensor)

# Compilação do Modelo
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
metrics = ['accuracy']
loss = 'binary_crossentropy'

model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

print(model.summary())
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 2, 75, 75)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 32, 75, 75)          │           1,632 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 75, 75)          │             300 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 32, 37, 37)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32, 37, 37)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 37, 37)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64, 37, 37)          │             148 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 64, 18, 18)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64, 18, 18)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 20736)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       2,654,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,679,073 (10.22 MB)
#  Trainable params: 2,678,849 (10.22 MB)
#  Non-trainable params: 224 (896.00 B)
# None

# %%
checkpoint_filepath = 'melhor_modelo_pesos.weights.keras'

checkpoint = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    mode='max',
    verbose=1,
    save_best_only=True
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    mode='min',
    verbose=1,
    patience=5,
    restore_best_weights=True
)

callbacks = [checkpoint, early_stopping]

# %%
epoch = 100
batch_size = 128
shuffle = True

X_train = np.asarray(X_train).astype('float32')
X_test = np.asarray(X_test).astype('float32')
Y_train = np.asarray(Y_train).astype('float32')
Y_test = np.asarray(Y_test).astype('float32')
X_validation = np.asarray(X_validation).astype('float32')
Y_validation = np.asarray(Y_validation).astype('float32')

# %%
training_time = time.time()

history = model.fit(
    x=X_train,
    y=Y_train,
    batch_size=batch_size,
    epochs=epoch,
    validation_data=(X_validation, Y_validation),
    shuffle=shuffle,
    verbose=1,
    callbacks=callbacks
)

training_time =  time.time()-training_time
print("tempo para treinamento da rede: {:0.3f} s".format(training_time))

tempo_total = time.time() - start_time
print("tempo total: {:0.3f} s".format(tempo_total))

accuracy = model.evaluate(X_test, Y_test, verbose=0)[1]
print(f"Acurácia do modelo carregado: {accuracy * 100:.2f}%")
# Out:
# Epoch 1/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5037 - loss: 14.6848
# Epoch 1: val_accuracy improved from -inf to 0.52659, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 0.5037 - loss: 14.6672 - val_accuracy: 0.5266 - val_loss: 10.5063
# Epoch 2/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5255 - loss: 9.6607
# Epoch 2: val_accuracy improved from 0.52659 to 0.53048, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 0.5256 - loss: 9.6521 - val_accuracy: 0.5305 - val_loss: 7.5657
# Epoch 3/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5236 - loss: 7.0633
# Epoch 3: val_accuracy did not improve from 0.53048
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.5237 - loss: 7.0583 - val_accuracy: 0.5298 - val_loss: 5.8533
# Epoch 4/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5320 - loss: 5.5350
# Epoch 4: val_accuracy did not improve from 0.53048
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.5319 - loss: 5.5319 - val_accuracy: 0.5272 - val_loss: 4.7406
# Epoch 5/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5518 - loss: 4.5343
# Epoch 5: val_accuracy improved from 0.53048 to 0.53178, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.5517 - loss: 4.5321 - val_accuracy: 0.5318 - val_loss: 3.9682
# Epoch 6/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5473 - loss: 3.8198
# Epoch 6: val_accuracy improved from 0.53178 to 0.53307, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.5473 - loss: 3.8181 - val_accuracy: 0.5331 - val_loss: 3.3789
# Epoch 7/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5427 - loss: 3.2767
# Epoch 7: val_accuracy did not improve from 0.53307
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.5428 - loss: 3.2754 - val_accuracy: 0.5331 - val_loss: 2.9531
# Epoch 8/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5517 - loss: 2.8531
# Epoch 8: val_accuracy did not improve from 0.53307
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.5517 - loss: 2.8521 - val_accuracy: 0.5324 - val_loss: 2.6002
# Epoch 9/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5577 - loss: 2.5223
# Epoch 9: val_accuracy improved from 0.53307 to 0.53437, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.5577 - loss: 2.5215 - val_accuracy: 0.5344 - val_loss: 2.3122
# Epoch 10/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5629 - loss: 2.2457
# Epoch 10: val_accuracy improved from 0.53437 to 0.55447, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.5629 - loss: 2.2450 - val_accuracy: 0.5545 - val_loss: 2.0725
# Epoch 11/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5686 - loss: 2.0104
# Epoch 11: val_accuracy improved from 0.55447 to 0.57198, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 0.5687 - loss: 2.0098 - val_accuracy: 0.5720 - val_loss: 1.8725
# Epoch 12/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5757 - loss: 1.8278
# Epoch 12: val_accuracy improved from 0.57198 to 0.64721, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.5756 - loss: 1.8273 - val_accuracy: 0.6472 - val_loss: 1.6994
# Epoch 13/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5741 - loss: 1.6604
# Epoch 13: val_accuracy did not improve from 0.64721
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.5741 - loss: 1.6600 - val_accuracy: 0.5409 - val_loss: 1.5600
# Epoch 14/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5916 - loss: 1.5254
# Epoch 14: val_accuracy did not improve from 0.64721
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.5916 - loss: 1.5250 - val_accuracy: 0.6427 - val_loss: 1.4361
# Epoch 15/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5931 - loss: 1.4066
# Epoch 15: val_accuracy improved from 0.64721 to 0.68742, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.5932 - loss: 1.4063 - val_accuracy: 0.6874 - val_loss: 1.3328
# Epoch 16/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5997 - loss: 1.3090
# Epoch 16: val_accuracy did not improve from 0.68742
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.5998 - loss: 1.3088 - val_accuracy: 0.6505 - val_loss: 1.2438
# Epoch 17/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6070 - loss: 1.2221
# Epoch 17: val_accuracy did not improve from 0.68742
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.6069 - loss: 1.2220 - val_accuracy: 0.6738 - val_loss: 1.1686
# Epoch 18/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6098 - loss: 1.1551
# Epoch 18: val_accuracy did not improve from 0.68742
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.6098 - loss: 1.1549 - val_accuracy: 0.6874 - val_loss: 1.1051
# Epoch 19/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5984 - loss: 1.0921
# Epoch 19: val_accuracy improved from 0.68742 to 0.69520, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 0.5985 - loss: 1.0920 - val_accuracy: 0.6952 - val_loss: 1.0409
# Epoch 20/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6215 - loss: 1.0354
# Epoch 20: val_accuracy improved from 0.69520 to 0.69909, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 103s 1s/step - accuracy: 0.6215 - loss: 1.0352 - val_accuracy: 0.6991 - val_loss: 0.9863
# Epoch 21/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6278 - loss: 0.9771
# Epoch 21: val_accuracy did not improve from 0.69909
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 102s 1s/step - accuracy: 0.6278 - loss: 0.9770 - val_accuracy: 0.6589 - val_loss: 0.9521
# Epoch 22/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6290 - loss: 0.9347
# Epoch 22: val_accuracy improved from 0.69909 to 0.70298, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 98s 1s/step - accuracy: 0.6291 - loss: 0.9346 - val_accuracy: 0.7030 - val_loss: 0.9043
# Epoch 23/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6395 - loss: 0.9006
# Epoch 23: val_accuracy did not improve from 0.70298
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.6395 - loss: 0.9005 - val_accuracy: 0.7017 - val_loss: 0.8685
# Epoch 24/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6375 - loss: 0.8683
# Epoch 24: val_accuracy did not improve from 0.70298
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.6376 - loss: 0.8682 - val_accuracy: 0.6842 - val_loss: 0.8369
# Epoch 25/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6529 - loss: 0.8344
# Epoch 25: val_accuracy improved from 0.70298 to 0.70623, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 0.6530 - loss: 0.8343 - val_accuracy: 0.7062 - val_loss: 0.8127
# Epoch 26/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6605 - loss: 0.8044
# Epoch 26: val_accuracy did not improve from 0.70623
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 99s 1s/step - accuracy: 0.6605 - loss: 0.8044 - val_accuracy: 0.6725 - val_loss: 0.7953
# Epoch 27/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6716 - loss: 0.7824
# Epoch 27: val_accuracy improved from 0.70623 to 0.71466, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6716 - loss: 0.7823 - val_accuracy: 0.7147 - val_loss: 0.7615
# Epoch 28/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6790 - loss: 0.7635
# Epoch 28: val_accuracy did not improve from 0.71466
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.6791 - loss: 0.7634 - val_accuracy: 0.6952 - val_loss: 0.7557
# Epoch 29/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6916 - loss: 0.7383
# Epoch 29: val_accuracy did not improve from 0.71466
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.6916 - loss: 0.7383 - val_accuracy: 0.6900 - val_loss: 0.7441
# Epoch 30/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6927 - loss: 0.7249
# Epoch 30: val_accuracy improved from 0.71466 to 0.71855, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.6928 - loss: 0.7249 - val_accuracy: 0.7185 - val_loss: 0.7170
# Epoch 31/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6999 - loss: 0.7106
# Epoch 31: val_accuracy did not improve from 0.71855
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.6999 - loss: 0.7106 - val_accuracy: 0.6654 - val_loss: 0.7263
# Epoch 32/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7064 - loss: 0.6946
# Epoch 32: val_accuracy did not improve from 0.71855
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7064 - loss: 0.6946 - val_accuracy: 0.7095 - val_loss: 0.6971
# Epoch 33/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7214 - loss: 0.6725
# Epoch 33: val_accuracy did not improve from 0.71855
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.7213 - loss: 0.6725 - val_accuracy: 0.7134 - val_loss: 0.6859
# Epoch 34/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7163 - loss: 0.6708
# Epoch 34: val_accuracy did not improve from 0.71855
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.7163 - loss: 0.6708 - val_accuracy: 0.7121 - val_loss: 0.6770
# Epoch 35/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7233 - loss: 0.6627
# Epoch 35: val_accuracy improved from 0.71855 to 0.72568, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.7233 - loss: 0.6627 - val_accuracy: 0.7257 - val_loss: 0.6639
# Epoch 36/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7277 - loss: 0.6518
# Epoch 36: val_accuracy did not improve from 0.72568
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.7277 - loss: 0.6519 - val_accuracy: 0.7062 - val_loss: 0.6781
# Epoch 37/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7384 - loss: 0.6495
# Epoch 37: val_accuracy did not improve from 0.72568
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.7384 - loss: 0.6495 - val_accuracy: 0.7056 - val_loss: 0.6677
# Epoch 38/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7322 - loss: 0.6431
# Epoch 38: val_accuracy did not improve from 0.72568
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.7323 - loss: 0.6430 - val_accuracy: 0.7231 - val_loss: 0.6494
# Epoch 39/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7393 - loss: 0.6304
# Epoch 39: val_accuracy improved from 0.72568 to 0.74384, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7393 - loss: 0.6304 - val_accuracy: 0.7438 - val_loss: 0.6352
# Epoch 40/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7521 - loss: 0.6161
# Epoch 40: val_accuracy improved from 0.74384 to 0.75551, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.7521 - loss: 0.6161 - val_accuracy: 0.7555 - val_loss: 0.6294
# Epoch 41/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7463 - loss: 0.6305
# Epoch 41: val_accuracy did not improve from 0.75551
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.7463 - loss: 0.6305 - val_accuracy: 0.7503 - val_loss: 0.6244
# Epoch 42/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7565 - loss: 0.6112
# Epoch 42: val_accuracy did not improve from 0.75551
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.7565 - loss: 0.6112 - val_accuracy: 0.7516 - val_loss: 0.6170
# Epoch 43/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7571 - loss: 0.6128
# Epoch 43: val_accuracy did not improve from 0.75551
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7571 - loss: 0.6128 - val_accuracy: 0.7244 - val_loss: 0.6422
# Epoch 44/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7497 - loss: 0.6187
# Epoch 44: val_accuracy improved from 0.75551 to 0.76719, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7498 - loss: 0.6185 - val_accuracy: 0.7672 - val_loss: 0.6007
# Epoch 45/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7591 - loss: 0.6069
# Epoch 45: val_accuracy did not improve from 0.76719
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7591 - loss: 0.6069 - val_accuracy: 0.7620 - val_loss: 0.5998
# Epoch 46/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7684 - loss: 0.5984
# Epoch 46: val_accuracy did not improve from 0.76719
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7683 - loss: 0.5985 - val_accuracy: 0.7665 - val_loss: 0.5993
# Epoch 47/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7615 - loss: 0.5981
# Epoch 47: val_accuracy improved from 0.76719 to 0.77302, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7614 - loss: 0.5981 - val_accuracy: 0.7730 - val_loss: 0.5925
# Epoch 48/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7608 - loss: 0.5891
# Epoch 48: val_accuracy did not improve from 0.77302
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7608 - loss: 0.5892 - val_accuracy: 0.7717 - val_loss: 0.5938
# Epoch 49/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7663 - loss: 0.5933
# Epoch 49: val_accuracy did not improve from 0.77302
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7663 - loss: 0.5933 - val_accuracy: 0.7724 - val_loss: 0.5854
# Epoch 50/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7727 - loss: 0.5822
# Epoch 50: val_accuracy improved from 0.77302 to 0.78016, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7727 - loss: 0.5823 - val_accuracy: 0.7802 - val_loss: 0.5833
# Epoch 51/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7743 - loss: 0.5861
# Epoch 51: val_accuracy did not improve from 0.78016
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7743 - loss: 0.5861 - val_accuracy: 0.7776 - val_loss: 0.5857
# Epoch 52/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7833 - loss: 0.5693
# Epoch 52: val_accuracy did not improve from 0.78016
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7832 - loss: 0.5695 - val_accuracy: 0.7776 - val_loss: 0.5870
# Epoch 53/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7731 - loss: 0.5727
# Epoch 53: val_accuracy improved from 0.78016 to 0.78210, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7731 - loss: 0.5727 - val_accuracy: 0.7821 - val_loss: 0.5810
# Epoch 54/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7814 - loss: 0.5689
# Epoch 54: val_accuracy did not improve from 0.78210
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7814 - loss: 0.5690 - val_accuracy: 0.7601 - val_loss: 0.6009
# Epoch 55/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7814 - loss: 0.5735
# Epoch 55: val_accuracy did not improve from 0.78210
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7813 - loss: 0.5735 - val_accuracy: 0.7665 - val_loss: 0.5847
# Epoch 56/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7887 - loss: 0.5596
# Epoch 56: val_accuracy did not improve from 0.78210
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7886 - loss: 0.5598 - val_accuracy: 0.7782 - val_loss: 0.5810
# Epoch 57/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7856 - loss: 0.5555
# Epoch 57: val_accuracy did not improve from 0.78210
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7855 - loss: 0.5556 - val_accuracy: 0.7613 - val_loss: 0.5880
# Epoch 58/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7878 - loss: 0.5558
# Epoch 58: val_accuracy improved from 0.78210 to 0.78470, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7878 - loss: 0.5559 - val_accuracy: 0.7847 - val_loss: 0.5734
# Epoch 59/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7879 - loss: 0.5519
# Epoch 59: val_accuracy did not improve from 0.78470
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7879 - loss: 0.5519 - val_accuracy: 0.7698 - val_loss: 0.5736
# Epoch 60/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7833 - loss: 0.5584
# Epoch 60: val_accuracy did not improve from 0.78470
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7833 - loss: 0.5584 - val_accuracy: 0.7782 - val_loss: 0.5769
# Epoch 61/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7900 - loss: 0.5621
# Epoch 61: val_accuracy did not improve from 0.78470
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7900 - loss: 0.5620 - val_accuracy: 0.7750 - val_loss: 0.5764
# Epoch 62/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7934 - loss: 0.5508
# Epoch 62: val_accuracy did not improve from 0.78470
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7933 - loss: 0.5508 - val_accuracy: 0.7821 - val_loss: 0.5688
# Epoch 63/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7876 - loss: 0.5501
# Epoch 63: val_accuracy did not improve from 0.78470
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.7875 - loss: 0.5502 - val_accuracy: 0.7834 - val_loss: 0.5701
# Epoch 64/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7876 - loss: 0.5509
# Epoch 64: val_accuracy did not improve from 0.78470
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.7876 - loss: 0.5509 - val_accuracy: 0.7769 - val_loss: 0.5711
# Epoch 65/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7925 - loss: 0.5469
# Epoch 65: val_accuracy did not improve from 0.78470
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.7924 - loss: 0.5470 - val_accuracy: 0.7821 - val_loss: 0.5713
# Epoch 66/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7972 - loss: 0.5476
# Epoch 66: val_accuracy did not improve from 0.78470
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.7972 - loss: 0.5476 - val_accuracy: 0.7834 - val_loss: 0.5639
# Epoch 67/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7878 - loss: 0.5532
# Epoch 67: val_accuracy did not improve from 0.78470
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.7879 - loss: 0.5532 - val_accuracy: 0.7789 - val_loss: 0.5658
# Epoch 68/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7959 - loss: 0.5454
# Epoch 68: val_accuracy improved from 0.78470 to 0.79442, saving model to melhor_modelo_pesos.weights.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7959 - loss: 0.5454 - val_accuracy: 0.7944 - val_loss: 0.5646
# Epoch 69/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7859 - loss: 0.5495
# Epoch 69: val_accuracy did not improve from 0.79442
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7859 - loss: 0.5495 - val_accuracy: 0.7853 - val_loss: 0.5621
# Epoch 70/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7949 - loss: 0.5512
# Epoch 70: val_accuracy did not improve from 0.79442
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7949 - loss: 0.5512 - val_accuracy: 0.7717 - val_loss: 0.5649
# Epoch 71/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7937 - loss: 0.5469
# Epoch 71: val_accuracy did not improve from 0.79442
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7937 - loss: 0.5469 - val_accuracy: 0.7730 - val_loss: 0.5658
# Epoch 72/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7952 - loss: 0.5414
# Epoch 72: val_accuracy did not improve from 0.79442
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.7953 - loss: 0.5414 - val_accuracy: 0.7899 - val_loss: 0.5540
# Epoch 73/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7954 - loss: 0.5391
# Epoch 73: val_accuracy did not improve from 0.79442
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7954 - loss: 0.5391 - val_accuracy: 0.7918 - val_loss: 0.5586
# Epoch 74/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7985 - loss: 0.5386
# Epoch 74: val_accuracy did not improve from 0.79442
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7985 - loss: 0.5386 - val_accuracy: 0.7782 - val_loss: 0.5616
# Epoch 75/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8091 - loss: 0.5330
# Epoch 75: val_accuracy did not improve from 0.79442
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.8091 - loss: 0.5330 - val_accuracy: 0.7691 - val_loss: 0.5707
# Epoch 76/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8055 - loss: 0.5276
# Epoch 76: val_accuracy did not improve from 0.79442
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.8054 - loss: 0.5277 - val_accuracy: 0.7750 - val_loss: 0.5611
# Epoch 77/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7990 - loss: 0.5316
# Epoch 77: val_accuracy did not improve from 0.79442
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.7989 - loss: 0.5316 - val_accuracy: 0.7743 - val_loss: 0.5567
# Epoch 77: early stopping
# Restoring model weights from the end of the best epoch: 72.
# tempo para treinamento da rede: 7297.415 s
# tempo total: 7339.977 s
# Acurácia do modelo carregado: 79.39%

# %%
training_time = time.time()

training_time =  time.time() - training_time

tempo_total = time.time() - start_time

accuracy = model.evaluate(X_test, Y_test, verbose=0)[1]

# Crie um dicionário para armazenar os dados
results = {
    'history': history.history,
    'training_time': training_time,
    'total_time': tempo_total,
    'accuracy': accuracy
}

# Salve o dicionário como um arquivo .npy
np.save('resultados_treinamento.npy', results)

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = list(range(len(loss)))

fig, ax1 = plt.subplots(figsize=(8, 4))

# Accuracy and Validation Accuracy (left y-axis)
color = 'tab:blue'
ax1.set_xlabel('Época')
ax1.set_ylabel('Acurácia', color=color)
ax1.plot(epochs, acc, color=color, label='Acurácia')
ax1.plot(epochs, val_acc, color='tab:cyan', label="Acurácia da validação")
ax1.tick_params(axis='y', labelcolor=color)
ax1.legend(loc='upper left')
#ax1.grid(True)

# Loss and Validation Loss (right y-axis)
ax2 = ax1.twinx()  # Create a twin axis
color = 'tab:red'
ax2.set_ylabel('Perda', color=color)
ax2.plot(epochs, loss, color=color, label='Perda')
ax2.plot(epochs, val_loss, color='tab:orange', label="Perda da validação")
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend(loc='upper right')
#ax2.grid(True)

plt.title("Histórico de Perda/Acurácia (Imagens Pristine)")
plt.tight_layout()
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
print('Acurácia no conjunto de teste:', accuracy)
print('Perda no conjunto de teste:', loss)
# Out:
# Acurácia no conjunto de teste: 0.7939079999923706
# Perda no conjunto de teste: 0.557451069355011

# %%
# ------------------------------------------------------------------------------
# Evaluate for TEST SET  ---> REPLICAR
# ------------------------------------------------------------------------------

from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
import matplotlib.pyplot as plt
import numpy as np

# predict
history_data = history
prob = model.predict(X_test)
pred =  (prob > 0.5).astype('int32') 

# measure confusion
labels=[0, 1]
cm = confusion_matrix(Y_test, pred, labels=labels)
cm = cm.astype('float')
cm_norm = cm / cm.sum(axis=1)[:, np.newaxis]
print("cm", cm)
print("cm_norm", cm_norm)

# Corrigindo a importação
fpr, tpr, thresholds = roc_curve(Y_test, prob, pos_label=1)
auc = roc_auc_score(Y_test, prob)
print("AUC:", auc)

#plotting
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Matrix de confusão (Teste)', y=1.08)
fig.colorbar(cax)

# Definir ticks antes de definir os rótulos
ax.set_xticks(range(len(labels)))  # Definir ticks para o eixo x
ax.set_yticks(range(len(labels)))  # Definir ticks para o eixo y

# Definir rótulos dos ticks
ax.set_xticklabels(labels)  # Remova o rótulo extra
ax.set_yticklabels(labels)

plt.xlabel('Previsão')
plt.ylabel('Verdadeiro')
fmt = '.2f'
thresh = cm_norm.max() / 2.
for i in range(cm_norm.shape[0]):
    for j in range(cm_norm.shape[1]):
        ax.text(j, i, format(cm_norm[i, j], fmt),
        ha="center", va="center",
        color="white" if cm_norm[i, j] < thresh else "black")
plt.show()
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step
# cm [[1169.  293.]
#  [ 343. 1281.]]
# cm_norm [[0.7995896 0.2004104]
#  [0.2112069 0.7887931]]
# AUC: 0.8711150458579582

# %%
history_data = history
prob = model.predict(X_test)
pred =  (prob > 0.5).astype('int32')

labels=[0, 1]
cm = confusion_matrix(Y_test, pred[:,0], labels=labels)
cm_norm = cm.astype(float) / cm.astype(float).sum(axis=1)[:, np.newaxis]

fig, axs = plt.subplots(1, 2, figsize=(15, 6))

sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', ax=axs[0])
axs[0].set_title('Matriz de confusão')
axs[0].set_xlabel('Previsão')
axs[0].set_ylabel('Verdadeiro')

sns.heatmap(cm_norm, annot=True, cmap='Blues', ax=axs[1])
axs[1].set_title('Matriz de confusão Normalizada')
axs[1].set_xlabel('Previsão')
axs[1].set_ylabel('Verdadeiro')
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step
# Text(792.3131313131312, 0.5, 'Verdadeiro')

# %%
#Parametros ---> REPLICAR

# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(Y_test, pred)
print('Accuracy: %f' % accuracy)

# precision tp / (tp + fp)
precision = precision_score(Y_test, pred)
print('Precision: %f' % precision)

# recall: tp / (tp + fn)
recall = recall_score(Y_test, pred)
print('Recall: %f' % recall)

# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(Y_test, pred)
print('F1 score: %f' % f1)

# brier score
bs = brier_score_loss(Y_test, prob)
print('Brier score: %f' % bs)
# Out:
# Accuracy: 0.793908
# Precision: 0.813850
# Recall: 0.788793
# F1 score: 0.801126
# Brier score: 0.147722

# %%
fpr, tpr, thresholds = roc_curve(Y_test, prob, pos_label=1)
auc = roc_auc_score(Y_test, prob)
print("\n AUC:", auc)

figsize=(5,5)
fig, axis1 = plt.subplots(figsize=figsize)
x_onetoone = y_onetoone = [0, 1]
plt.plot(fpr, tpr, 'r-')
plt.plot(x_onetoone, y_onetoone, 'k--',  label="1-1")
plt.legend(loc=0)
plt.title("Característica Opercaional do Receptor (ROC)")
plt.xlabel("Falso Positivo (1 - Especificidade)")
plt.ylabel("Verdadeiro Positivo (Seletividade)")
plt.tight_layout()
# Out:
#  AUC: 0.8711150458579582

# %%
bs = brier_score_loss(Y_test, prob)
print('Brier score: %f' % bs)

print('\n', classification_report(Y_test, pred))
# Out:
# Brier score: 0.147722
#
#                precision    recall  f1-score   support
#
#          0.0       0.77      0.80      0.79      1462
#          1.0       0.81      0.79      0.80      1624
#
#     accuracy                           0.79      3086
#    macro avg       0.79      0.79      0.79      3086
# weighted avg       0.79      0.79      0.79      3086

# %%
import numpy as np
import random

# ... (seu código que define model, X_test, Y_test)

# Fazer previsões e calcular o erro
prob = model.predict(X_test)
pred = (prob > 0.5).astype("int32")
Pred_error = pred[:, 0] - Y_test

random.seed(2024)  # Define a semente ANTES da amostragem
num_samples = len(X_test) #  Usar todos os dados com a seed fixa

indices = random.sample(range(len(X_test)), num_samples) # Embaralha os índices com a seed

# Cria listas vazias para armazenar os índices de cada classe
FN_indices = []
FP_indices = []
TN_indices = []
TP_indices = []

# Classifica os índices com base nas previsões e nos valores reais
for i in indices:
    if Pred_error[i] == 1:
        FN_indices.append(i)
    elif Pred_error[i] == -1:
        FP_indices.append(i)
    elif (Y_test[i] + pred[i, 0]) == 0:
        TN_indices.append(i)
    elif (Y_test[i] + pred[i, 0]) == 2:
        TP_indices.append(i)



# Calcula e imprime as porcentagens
print(
    f"Número de FN, FP, TN, TP = {len(FN_indices)}, {len(FP_indices)}, {len(TN_indices)}, {len(TP_indices)}",
    end=" ",
)
print(
    "({:.1f}%, {:.1f}%, {:.1f}%, {:.1f}%)".format(
        100 * len(FN_indices) / num_samples,
        100 * len(FP_indices) / num_samples,
        100 * len(TN_indices) / num_samples,
        100 * len(TP_indices) / num_samples,
    )
)



# Agora você tem as listas FN_indices, FP_indices, TN_indices e TP_indices
# contendo os índices correspondentes a cada classe, usando a ordem 
# aleatória definida pela seed(42).
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step
# Número de FN, FP, TN, TP = 293, 343, 1169, 1281 (9.5%, 11.1%, 37.9%, 41.5%)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import gaussian_filter
from matplotlib.colors import LogNorm
import random

# ... (seu código que define model, X_test, Y_test)

# Fazer previsões e calcular o erro, etc. (mesmo código do bloco anterior)
# ...


#  (Removido: Dicionários examples e example_indices - não são mais necessários)


# Plota os exemplos usando os índices calculados anteriormente
all_examples = []
classificacoes = []


indices_por_classe = {
    'VN': TN_indices, 
    'FN': FN_indices,
    'VP': TP_indices,
    'FP': FP_indices,
}


for classe, indices in indices_por_classe.items():
    all_examples.extend([X_test[i, 1] for i in indices[:4]]) # Seleciona até 4 exemplos de cada classe
    classificacoes.extend([classe] * min(4, len(indices))) # Adiciona a classificação correta


fig1, axes = plt.subplots(4, 4, figsize=(10, 10))
fig1.subplots_adjust(hspace=0.5, wspace=0.5)

for i, (image, classe) in enumerate(zip(all_examples, classificacoes)):
    random.seed(2024 + i)  # Define uma semente para reprodutibilidade, mas não afeta a seleção

    ax = axes.flat[i]
    ax.axis("off")

    # Normaliza e aplica filtro Gaussiano
    image = (image - image.min()) / (image.max() - image.min() + 1e-8)
    image = gaussian_filter(image, sigma=1)

    ax.imshow(image, aspect='auto', cmap='viridis', norm=LogNorm())
    ax.set_title(classe)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import gaussian_filter
from matplotlib.colors import LogNorm
import random

# ... (seu código anterior, incluindo a definição de model, X_test, Y_test,
# o cálculo das previsões e a criação dos índices *_indices)

# ...


# Plota exemplos aleatórios, duas imagens por linha, com tamanho menor
num_classes = len(indices_por_classe)
fig1, axes = plt.subplots(num_classes // 2, 2, figsize=(8, 4 * (num_classes // 2)))  # Tamanho menor
fig1.subplots_adjust(hspace=0.5, wspace=0.5)

all_examples = []
classificacoes = []

rng = random.Random(2024) # Gerador de números aleatórios com semente fixa


for classe, indices in indices_por_classe.items():
    if indices: # Verifica se há exemplos para a classe.
        random_index = rng.choice(indices) # Seleciona um índice ALEATÓRIO
        all_examples.append(X_test[random_index, 1])
        classificacoes.append(classe)
    else:
        print(f"Nenhum exemplo encontrado para a classe {classe}. Pulando.")


for i, (image, classe) in enumerate(zip(all_examples, classificacoes)):
    ax = axes.flat[i]
    ax.axis("off")

    # Normaliza e aplica filtro Gaussiano
    image = (image - image.min()) / (image.max() - image.min() + 1e-8)
    image = gaussian_filter(image, sigma=1)

    ax.imshow(image, aspect='auto', cmap='viridis', norm=LogNorm())
    ax.set_title(classe)

plt.show()
